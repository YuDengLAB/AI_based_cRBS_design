# %%
import numpy as np
import pandas as pd

data=pd.read_csv("./seq/cRBS_long_N_0_1129.csv")#read csv file
data=pd.read_csv("./seq/cRBS_long_N_20_1129.csv")
data=pd.read_csv("./seq/cRBS_long_R_0_1202.csv")
data=pd.read_csv("./seq/cRBS_long_R_20_1202.csv")
cRBS=data.values.tolist()
print(cRBS)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8a95b76cd94f> in <module>
#       2 import pandas as pd
#       3
# ----> 4 data=pd.read_csv("./seq/cRBS_long_N_0_1129.csv")#read csv file
#       5 data=pd.read_csv("./seq/cRBS_long_N_20_1129.csv")
#       6 data=pd.read_csv("./seq/cRBS_long_R_0_1202.csv")
#
# ...

# %%
import operator
from functools import reduce
cRBS=reduce(operator.add,cRBS)
print(cRBS)
cRBS=np.array(cRBS)
print(cRBS)

# %%
np.save('./seq/cRBS_long_N_0_1129',cRBS,allow_pickle=True,fix_imports=True)
np.save('./seq/cRBS_long_N_20_1129',cRBS,allow_pickle=True,fix_imports=True)
np.save('./seq/cRBS_long_R_0_1202',cRBS,allow_pickle=True,fix_imports=True)
np.save('./seq/cRBS_long_R_0_1202',cRBS,allow_pickle=True,fix_imports=True)

# %%
import numpy as np
import pandas as pd

data=pd.read_csv("./seq/Fluorescence_intensity_N_0_1129.csv")#read csv file
data=pd.read_csv("./seq/Fluorescence_intensity_N_20_1129.csv")
data=pd.read_csv("./seq/Fluorescence_intensity_R_0_1202.csv")
data=pd.read_csv("./seq/Fluorescence_intensity_R_20_12020.csv")
Flu=data.values.tolist()
print(Flu)
# Out:
# [[4.7], [42.1], [13.3], [32.5], [36.7], [9.9], [4.6], [39.7], [9.1], [24.2], [13.4], [32.6], [19.3], [13.0], [40.7], [20.7], [34.4], [40.3], [17.1], [18.0], [30.2], [13.9], [17.1], [41.8], [17.5], [13.4], [6.0], [8.6], [25.3], [18.7], [26.0], [18.6], [15.8], [18.4], [16.5], [16.4], [26.4], [15.9], [33.1], [2.0], [18.8], [11.8], [28.1], [2.7], [49.4], [14.5], [36.8], [23.9], [11.6], [8.7], [36.6], [19.4], [42.5], [24.1], [23.2], [36.0], [19.5], [20.4], [22.5], [30.9], [18.3], [16.9], [16.6], [30.3], [29.9], [43.1], [8.3], [32.9], [28.6], [36.3], [25.8], [27.8], [38.1], [9.4], [35.5], [32.6], [21.0], [15.4], [12.0], [35.2], [30.0], [7.9], [18.2], [18.1], [8.1], [5.8], [17.6], [29.2], [17.7], [17.9], [38.1], [30.2], [15.0], [23.9], [37.5], [26.3], [24.5], [23.7], [19.9], [16.1], [18.8], [25.6], [26.9], [18.0], [33.5], [18.7], [43.7], [13.1], [38.9], [10.0], [8.8], [24.1], [21.0], [32.8], [25.3], [29.0], [27.1], [16.4], [16.2], [27.9], [37.8], [23.6], [23.8], [24.8], [32.4], [15.4], [2.8
# ...

# %%
import operator
from functools import reduce
Flu=reduce(operator.add,Flu)
Flu=["%.2f" % x for x in Flu]
Flu=np.array(Flu)
print(Flu)
# Out:
# ['4.70' '42.10' '13.30' ... '25.10' '20.00' '49.50']

# %%
np.save('./seq/Fluorescence_intensity_N_0_1129',Flu,allow_pickle=True,fix_imports=True)
np.save('./seq/Fluorescence_intensity_N_20_1129',Flu,allow_pickle=True,fix_imports=True)
np.save('./seq/Fluorescence_intensity_R_0_1202',Flu,allow_pickle=True,fix_imports=True)
np.save('./seq/Fluorescence_intensity_R_20_1202',Flu,allow_pickle=True,fix_imports=True)
